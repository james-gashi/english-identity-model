# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from collections import Counter
from nltk.tokenize import word_tokenize


uniform_excerpts = pd.read_csv('./data/gutenberg/uniform_excerpts.csv')

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=200)
train, test = train_test_split(uniform_excerpts, test_size=0.2, random_state=200)

# %%
X_train = train.drop("label", axis = 1)
X_test = test.drop("label", axis = 1)

y_train = train["label"]
y_test = test["label"]

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
print("train eras", y_train.value_counts())
print("test eras", y_test.value_counts())
# Out:
# (4800, 2) (1200, 2) (4800,) (1200,)
# train eras label
# 1500s    818
# 1600s    806
# 1800s    799
# 1700s    797
# 1400s    792
# 1900s    788
# Name: count, dtype: int64
# test eras label
# 1900s    212
# 1400s    208
# 1700s    203
# 1800s    201
# 1600s    194
# 1500s    182
# Name: count, dtype: int64

# %%
"""
    features to look at first:
    average word length
    average sentance length
    parts of speech frequencies
    frequencies of certain words/spellings
"""
# Out:
# '\n    features to look at first:\n    average word length\n    average sentance length\n    parts of speech frequencies\n    frequencies of certain words/spellings\n'

# %%
"""
    get list of words from 1400s samples
    get vocab as well
"""
# list of strings, each denoting a text excerpt from the 1400s
samples_1400s = train[train["label"] == "1400s"]["text"].tolist() 
vocab_1400s = set()
words_list_1400s = []
for sample in samples_1400s:
    for word in word_tokenize(sample):
        vocab_1400s.add(word.lower())
        words_list_1400s.append(word.lower())

# %%
"""
    get list of words from 1500s samples
    get vocab as well
"""
samples_1500s =  train[train["label"] == "1500s"]["text"].tolist() 

vocab_1500s = set()
words_list_1500s = []
for sample in samples_1500s:
    for word in word_tokenize(sample):
        vocab_1500s.add(word.lower())
        words_list_1500s.append(word.lower())

# %%
"""
    get list of words from 1600s samples
    get vocab as well
"""
samples_1600s =  train[train["label"] == "1600s"]["text"].tolist() 

vocab_1600s = set()
words_list_1600s = []
for sample in samples_1600s:
    for word in word_tokenize(sample):
        vocab_1600s.add(word.lower())
        words_list_1600s.append(word.lower())

# %%
"""
    get list of words from 1700s samples
    get vocab as well
"""
samples_1700s =  train[train["label"] == "1700s"]["text"].tolist() 

vocab_1700s = set()
words_list_1700s = []
for sample in samples_1700s:
    for word in word_tokenize(sample):
        vocab_1700s.add(word.lower())
        words_list_1700s.append(word.lower())

# %%
"""
    get list of words from 1800s samples
    get vocab as well
"""
samples_1800s =  train[train["label"] == "1800s"]["text"].tolist() 

vocab_1800s = set()
words_list_1800s = []
for sample in samples_1800s:
    for word in word_tokenize(sample):
        vocab_1800s.add(word.lower())
        words_list_1800s.append(word.lower())

# %%
"""
    get list of words from 1900s samples
    get vocab as well
"""
samples_1900s =  train[train["label"] == "1900s"]["text"].tolist() 

vocab_1900s = set()
words_list_1900s = []
for sample in samples_1900s:
    for word in word_tokenize(sample):
        vocab_1900s.add(word.lower())
        words_list_1900s.append(word.lower())

# %%
only_1400s_words = [word for word in words_list_1400s if word not in vocab_1500s and word not in vocab_1600s and word not in vocab_1700s and word not in vocab_1800s]

counter14s = Counter(only_1400s_words)
print(counter14s.most_common())
refined_1400s_words = set(["suche", "thay", "wyll", "dyd", "mynde", "woulde", "thyng", "lyfe", "theyr", "thynke","muche","tyme","apon","nowe"])
# Out:
# [('||', 68), ('_spaniards_', 63), ('suche', 52), ('yf', 49), ('_ogy._', 47), ('_me._', 43), ('wyll', 43), ('dyd', 38), ('florentines', 37), ('mynde', 31), ('doo', 31), ('boleyn', 31), ('thei', 29), ('woulde', 29), ('thê', 28), ('_spv._', 27), ('eula', 27), ('_hedo._', 26), ('thay', 26), ('shuld', 26), ('thyng', 24), ('lyfe', 23), ('gospell', 22), ('nowe', 21), ('theyr', 21), ('thynke', 21), ('xantip', 20), ('_ward_', 20), ('signory', 19), ('augustana', 19), ('quod', 18), ('frome', 18), ('lytle', 18), ('muche', 17), ('_boni._', 17), ('wyse', 17), ('boke', 17), ('agayne', 16), ('_he._', 16), ('_bea._', 16), ('tyme', 16), ('apon', 16), ('cannius', 16), ('poli', 16), ('_hispaniola_', 16), ('nothyng', 15), ('lyue', 15), ('mã', 15), ('wyfe', 15), ('_henry', 15), ('boleyn._', 15), ('observances', 14), ('_sp._', 14), ('canni', 13), ('woord', 13), ('venetians', 13), ('praye', 13), ('eyther', 13), ('xantippa', 13), ('eulalia', 13), ('dede', 13), ('intemperance', 13), ('luther', 13), ('lombardy', 12), ('fynde', 12), ('fyre', 12), ('owt', 12), ('hande', 12), ('1528', 12), ('wolde', 11), ('poliphe', 11), ('_indian_', 11), ('pape', 11), ('ryght', 11), ('xan', 11), ('moche', 11), ('_byzantium_', 11), ('faute', 10), ('kepe', 10), ('churche', 10), ('elles', 10), ('wer', 10), ('whē', 10), ('whan', 10), ('gyue', 10), ('_john_', 10), ('emongist', 10), ('thes', 10), ('thaym', 10), ('_spu._', 9), ('veniarum', 9), ('anye', 9), ('husbande', 9), ('wherfore', 9), ('_spanish_', 9), ('aboute', 9), ('falsely', 9), ('bagnio', 9), ('oure', 9), ('hadde', 9), ('precyous', 9), ('saynt', 9), ('_of_', 9), ('wyne', 8), ('lucca', 8), ('kynde', 8), ('wyth', 8), ('dei', 8), ('greate', 8), ('propter', 8), ('newe', 8), ('holy-days', 8), ('fasts', 8), ('maried', 8), ('slaughters', 8), ('wykyd', 8), ('godlye', 8), ('lawe', 8), ('poliphemus', 8), ('handes', 8), ('thre', 8), ('_justinian_', 8), ('_simeon_', 8), ('trow', 7), ('dooeth', 7), ('syde', 7), ('maruayle', 7), ('_hed._', 7), ('thinge', 7), ('ferrando', 7), ('noo', 7), ('doctryne', 7), ('youre', 7), ('fayre', 7), ('agaynst', 7), ('satisfactions', 7), ('womā', 7), ('worlde', 7), ('sayntes', 7), ('galleries', 7), ('mery', 7), ('plesure', 7), ('rulers', 7), ('_zonaras_', 7), ('nedes', 7), ('apere', 7), ('nother', 7), ('thayr', 7), ('laye', 7), ('thã', 7), ('alfonso', 7), ('corso', 7), ('_v_', 7), ('dom._', 6), ('_h._', 6), ('coulde', 6), ('whyche', 6), ('above-mentioned', 6), ('doeth', 6), ('lyuynge', 6), ('pontiffs', 6), ('romagna', 6), ('_propontis_', 6), ('doughter', 6), ('myne', 6), ('heartes', 6), ('afterwarde', 6), ('plage', 6), ('propitiator', 6), ('nets', 6), ('foods', 6), ('testifies', 6), ('_arcadius_', 6), ('piero', 6), ('speaketh', 6), ('wyues', 6), ('ordinance', 6), ('_stephanus_', 6), ('_byzas_', 6), ('countre', 6), ('_galata_', 6), ('whã', 6), ('menne', 6), ('nothynge', 6), ('xā', 6), ('redy', 6), ('eu', 6), ('cornaro', 6), ('_castile_', 6), ('xantyppa', 6), ('mynd', 6), ('_alphonsus_', 6), ('prayse', 6), ('declaringe', 6), ('shrowde', 6), ('erasmus', 6), ('rebuilt', 6), ('hapned', 6), ('furth', 5), ('moost', 5), ('euyll', 5), ('======================================================================', 5), ('wittenberg', 5), ('ecclesie', 5), ('facit', 5), ('animam', 5), ('quam', 5), ('piccinino', 5), ('doughters', 5), ('ps', 5), ('_promontory_', 5), ('vtterly', 5), ('sorow', 5), ('prynce', 5), ('almes', 5), ('meriting', 5), ('payre', 5), ('soo', 5), ('teache', 5), ('arno', 5), ('salvestro', 5), ('constantine', 5), ('baths', 5), ('_nicephorus_', 5), ('yowr', 5), ('howse', 5), ('syr', 5), ('testimonies', 5), ('pecuniis', 5), ('mylke', 5), ('sene', 5), ('lerned', 5), ('doone', 5), ('gere', 5), ('tuscany', 5), ('anone', 5), ('betwene', 5), ('_cott', 5), ('forsoth', 5), ('inoughe', 5), ('naye', 5), ('whome', 5), ('bardi', 5), ('frescobaldi', 5), ('docendi', 5), ('christiani', 5), ('religioso', 5), ('recreations', 5), ('saythe', 5), ('galeazzo', 5), ('vpe', 5), ('discompos', 5), ('epicures', 5), ('broght', 5),  ...

# %%
only_1500s_words = [word for word in words_list_1500s if word not in vocab_1400s and word not in vocab_1600s and word not in vocab_1700s and word not in vocab_1800s]

counter15s = Counter(only_1500s_words)
print(counter15s.most_common())
refined_1500s_words = set(["looke","beene","keepe","queene","speach","crowne","feete","seemes","returne"])
refinded_old_words_vocab = refined_1400s_words | refined_1500s_words
# Out:
# [('giue', 31), ('exeunt', 22), ('sonne', 21), ('iohn', 20), ('timon', 19), ('keepe', 16), ('looke', 15), ('clo', 14), ('beene', 14), ('mace', 14), ('beleeue', 13), ('cassio', 13), ('hauing', 11), ('foure', 11), ('y^e', 11), ('queene', 10), ('dury', 10), ('brutus', 9), ('speach', 9), ('crowne', 9), ('feete', 9), ('angelo', 9), ('lucius', 8), ('themselues', 8), ('seemes', 8), ('marcus', 8), ('prithee', 8), ('prin', 8), ('iew', 8), ('saies', 8), ('deere', 8), ('leaues', 8), ('yorke', 8), ('manie', 8), ('navarre', 8), ('priuiledges', 8), ('iustice', 8), ('grated', 8), ('graue', 7), ('tamora', 7), ('bru', 7), ('launcelet', 7), ('appeare', 7), ('veal', 7), ('prethee', 7), ('demetrius', 7), ('knowne', 7), ('iul', 7), ('returne', 7), ('losse', 7), ('macbeth', 7), ('orl', 7), ('cassi', 7), ('zeale', 7), ('royall', 7), ('_other', 7), ('//', 7), ('warwick', 7), ('reuenge', 6), ('betweene', 6), ("i'th", 6), ('lancaster', 6), ('claudio', 6), ('blesse', 6), ('iobbe', 6), ('counsaile', 6), ('aaron', 6), ('sicke', 6), ('euerie', 6), ('ayre', 6), ('iago', 6), ('sil', 6), ('hermia', 6), ('blowes', 6), ('mn', 6), ('forsworn', 6), ('ariel', 6), ('cominius', 6), ('toby', 6), ('bardolph', 6), ('towne', 6), ('worthie', 6), ('minced', 6), ('mince', 6), ('beef-suet', 6), ('pitty', 6), ('bawd', 6), ('authoritie', 6), ('martius', 6), ('quicke', 6), ('woo', 5), ('jaques', 5), ('troth', 5), ('cinamon', 5), ('crosse', 5), ('womans', 5), ('diuell', 5), ('giues', 5), ('yeere', 5), ('mistris', 5), ('foote', 5), ("o'th", 5), ('mariana', 5), ('loued', 5), ('_ham._', 5), ('talbot', 5), ('gratiano', 5), ('seb', 5), ('liuing', 5), ('troilus', 5), ('quixote', 5), ('dulcinea', 5), ('booke', 5), ('_exeunt', 5), ('corio', 5), ('ber', 5), ('deuise', 5), ('weake', 5), ('cade', 5), ('nayles', 5), ('roare', 5), ('berowne', 5), ('louing', 5), ('bosome', 5), ('men._', 5), ('lear', 5), ('sweare', 5), ('iacke', 5), ('alcibiades', 5), ('peece', 5), ('locrine', 5), ('paulina', 4), ('saturnine', 4), ('meete', 4), ('menenius', 4), ('aduantage', 4), ('loues', 4), ('greene', 4), ('currans', 4), ('lard', 4), ('murther', 4), ('flo', 4), ('wooe', 4), ('enobarbus', 4), ('scena', 4), ('bast', 4), ('heeles', 4), ('heauens', 4), ('indeede', 4), ('lauinia', 4), ('aswell', 4), ('meate', 4), ('hounds', 4), ('whiles', 4), ('neptune', 4), ('weepe', 4), ('vntill', 4), ('conuenient', 4), ('costard', 4), ('1990-1993', 4), ('inc.', 4), ('carnegie', 4), ('mellon', 4), ('signior', 4), ('cardinall', 4), ('fra', 4), ('stirre', 4), ('briefe', 4), ('pandarus', 4), ('hubert', 4), ('buriall', 4), ('anthonio', 4), ('bottome', 4), ('lysander', 4), ('adr', 4), ('ducats', 4), ('driue', 4), ('yeeres', 4), ('mal', 4), ('clow', 4), ('ol', 4), ('griefe', 4), ('bookes', 4), ('learne', 4), ('caius', 4), ('cassius', 4), ('posthumus', 4), ('quarrell', 4), ('desdemona', 4), ('seuen', 4), ('laf', 4), ('sexe', 4), ('dice', 4), ('bianca', 4), ('villaine', 4), ('ob', 4), ('sillable', 4), ('speciall', 4), ('blacke', 4), ('suites', 4), ('recesse', 4), ('vsed', 4), ('stew', 4), ('artichocks', 4), ('cheese', 4), ('falstaffe', 4), ('iest', 4), ('lookes', 4), ('colevile', 4), ('arrowes', 4), ('iu', 4), ('cam', 4), ('sal', 4), ('_varna', 4), ('_cel._', 4), ('hornes', 4), ('anon', 4), ('caphis', 4), ("doo't", 4), ('edg', 4), ('ajax', 4), ('faile', 4), ('prospero', 4), ('bodie', 4), ('glost', 4), ('_hor._', 4), ('reueng', 4), ('iaq', 4), ('/', 4), ('_text', 4), ('philosophie', 3), ('suffolk', 3), ('orlando', 3), ('legge', 3), ('fatall', 3), ('bassianus', 3), ('drowne', 3), ('wilde', 3), ('dreame', 3), ('imogen', 3), ('constable', 3), ('orleance', 3), ('chopped', 3), ('verjuyce', 3), ('_pylonas_', 3), ('gon', 3), ('parley', 3), ('touchstone', 3), ('signes', 3), ('streame', 3), ('braue', 3), ('alarum', 3), ('westmerland', 3), ('vnlesse', 3), ('bleed', 3), ('whats', 3), ('clowne', 3), ('lancelet', 3), ('bouge', 3), ('rul', 3), ('sauing', 3), ('reuerence', 3), ('luciana', 3), ('cochinile', 3), ('chide', 3), ('por', 3), ('giotto', 3),  ...

# %%
modern_words_list = words_list_1600s + words_list_1700s + words_list_1800s + words_list_1900s
old_words_vocab = vocab_1400s | vocab_1500s
only_modern_words = []
for word in modern_words_list:
    if word not in old_words_vocab:
        # print(word,"\n")
        only_modern_words.append(word)

counter_modern = Counter(only_modern_words)
print(counter_modern.most_common())
refinded_modern_words_vocab = set(["beneath", "class", "system", "interest", "american", "america", "started","stopped","expression","blue"])
# Out:
# [("'ve", 72), ('interest', 51), ('america', 43), ('mr', 40), ('blue', 39), ('dr.', 39), ('american', 37), ('rock', 35), ('....', 34), ('system', 34), ('started', 32), ('beneath', 31), ('stopped', 30), ('class', 30), ('colonel', 28), ('animals', 28), ('bank', 28), ('weeks', 27), ('informed', 26), ('movement', 26), ('bit', 26), ("ev'ry", 25), ('dressed', 25), ('expression', 25), ('indian', 25), ('generous', 24), ('shoulder', 23), ('floor', 23), ('planet', 23), ('national', 23), ('occasionally', 23), ('color', 23), ('interested', 22), ('ve', 22), ('animal', 21), ('j.', 20), ('busy', 20), ('frank', 20), ('station', 20), ('cape', 19), ('surprise', 19), ('sentiments', 19), ('century', 19), ('british', 19), ('gun', 19), ('central', 19), ('dropped', 19), ('attempted', 18), ('listened', 18), ('slightly', 18), ('empty', 18), ('task', 18), ('row', 17), ('turns', 17), ('features', 17), ('hotel', 17), ('college', 17), ('assembly', 17), ('vanity', 17), ('lately', 17), ('remarks', 17), ('w.', 17), ('explain', 17), ('kitchen', 17), ('atlantic', 17), ('listening', 17), ('box', 17), ('police', 17), ('sailor', 17), ('stared', 17), ('total', 17), ('swept', 17), ('grass', 17), ('jim', 17), ('charms', 16), ('flying', 16), ('sung', 16), ('farmer', 16), ('wheel', 16), ('played', 16), ('exclaimed', 16), ('ice', 16), ('major', 16), ('claims', 16), ('somehow', 16), ('didn', 16), ('telephone', 16), ('to-day', 15), ('rays', 15), ('january', 15), ('fontaine', 15), ('memoirs', 15), ('reflection', 15), ('wi', 15), ('ugly', 15), ('fig', 15), ('curiosity', 15), ('ai', 15), ('0', 15), ('somebody', 15), ('splendid', 15), ('path', 15), ('congress', 15), ('struggle', 15), ('average', 15), ('examination', 15), ('mexico', 15), ('trail', 15), ('maybe', 15), ('swung', 15), ('managed', 14), ('astonished', 14), ('rivers', 14), ('wo', 14), ('schools', 14), ('odd', 14), ('moments', 14), ('britain', 14), ('bowed', 14), ('dozen', 14), ('whispered', 14), ('adding', 14), ('smoke', 14), ('stepped', 14), ('committee', 14), ('realized', 14), ('novels', 13), ('instances', 13), ('valuable', 13), ('luck', 13), ('mademoiselle', 13), ('maintenon', 13), ('favourable', 13), ('operations', 13), ('imagined', 13), ('softly', 13), ('verses', 13), ('disappeared', 13), ('pause', 13), ('gloom', 13), ('vanished', 13), ('admire', 13), ('mysterious', 13), ('marines', 13), ('historical', 13), ('museum', 13), ('martian', 13), ('household', 12), ('compound', 12), ('mixed', 12), ('interview', 12), ('conceal', 12), ("d'orleans", 12), ('female', 12), ('gang', 12), ('publication', 12), ('ceremony', 12), ('hung', 12), ('essential', 12), ('angles', 12), ('connected', 12), ('site', 12), ('esq.', 12), ('breeze', 12), ('washington', 12), ('spell', 12), ('china', 12), ('napoleon', 12), ('murmured', 12), ('wouldn', 12), ('bottle', 12), ('area', 12), ('objection', 11), ('wave', 11), ('bone', 11), ('pointed', 11), ('lock', 11), ('finish', 11), ('experiment', 11), ('solution', 11), ('luxury', 11), ('clean', 11), ('theory', 11), ('amidst', 11), ('experiments', 11), ('editor', 11), ('prime', 11), ('crop', 11), ('accounts', 11), ('staring', 11), ('sandy', 11), ('ringing', 11), ('negroes', 11), ('visits', 11), ('artist', 11), ('intentions', 11), ('facts', 11), ('lifted', 11), ('positive', 11), ('adult', 11), ('reflected', 11), ('invisible', 11), ('frightened', 11), ('esq', 11), ('student', 11), ('introduced', 11), ('objections', 11), ('hostile', 11), ('sprang', 11), ('yards', 11), ('paused', 11), ('rear', 11), ('settlement', 11), ('closer', 11), ('yard', 11), ('occasional', 11), ('suggested', 11), ('asking', 11), ('trip', 11), ('medical', 11), ('nodded', 11), ('crazy', 11), ('subspecies', 11), ('rocket', 11), ('mansoul', 10), ('seriously', 10), ('roll', 10), ('inquiry', 10), ('warmth', 10), ('novel', 10), ('elegance', 10), ('dr', 10), ('extremity', 10), ('austria', 10), ('charm', 10), ('formidable', 10), ('fired', 10), ('selected', 10), ('shining', 10), ('compleat', 10), ("o'clock", 10), ('minor', 10), ('limbs', 10) ...

# %%
print("Manually refined 1400s only vocab", refined_1400s_words)
print("Manually refined 1500s only vocab", refined_1500s_words)
print("Manually refined vocab from more modern time", refinded_modern_words_vocab)
print("Full set of words found only in 1400s and 1500s texts...", (only_1400s_words + only_1500s_words)[:25])
print("Full set of words found only in 16, 17, 18, 1900s texts...", only_modern_words[:25])
# Out:
# Manually refined 1400s only vocab {'woulde', 'theyr', 'suche', 'mynde', 'dyd', 'thynke', 'nowe', 'thyng', 'thay', 'wyll', 'lyfe', 'apon', 'tyme', 'muche'}
# Manually refined 1500s only vocab {'beene', 'queene', 'feete', 'crowne', 'looke', 'speach', 'seemes', 'returne', 'keepe'}
# Manually refined vocab from more modern time {'american', 'system', 'expression', 'class', 'america', 'blue', 'started', 'interest', 'stopped', 'beneath'}
# Full set of words found only in 1400s and 1500s texts... ['leviathan', 'wolde', 'suche', 'faute', 'trow', 'wyne', 'canni', 'yf', 'skynne', 'whê', 'wyne', 'poliphe', 'nothyng', 'heuynly', '_baraclona_', '_december', 'dom._', '1542', 'promulgated', '_madera_', 'requir', 'enormities', 'perdition', 'councellors', 'conscientious']
# Full set of words found only in 16, 17, 18, 1900s texts... ['jerusalem', 'replies', 'killers', 'baptized', '37', 'symbolize', 'messiah', '_athanasius_', '_quæst._', '20.', 'scruples', 'temptation', 'venomous', '_he', 'approve', 'refreshed', 'anecdote', 'marly', 'bergheyck', 'campaign', 'stopped', 'pavilions', 'desmarets', 'chamillart', 'finances']

# %%
# def contains_old_word(example):
#     return {word : 1 if word in example else 0 for word in refinded_old_words_vocab}

def contains_1400s_word_refined_list(example): 
    return {word : 1 if word in example else 0 for word in refined_1400s_words}

def contains_1400s_word_large_list(example): 
    return {word : 1 if word in example else 0 for word in only_1400s_words[:100]}

def contains_1500s_word_refined_list(example): 
    return {word : 1 if word in example else 0 for word in refined_1500s_words}

def contains_1500s_word_large_list(example): 
    return {word : 1 if word in example else 0 for word in only_1500s_words[:100]}

def contains_new_word_refined_list(example): 
    return {word : 1 if word in example else 0 for word in refinded_modern_words_vocab}

def contains_new_word_large_list(example): 
    return {word : 1 if word in example else 0 for word in modern_words_list[:250]}

# def count_old_word(example):
#     return {word : 1 if word in example else 0 for word in refinded_modern_words_vocab}

def create_feature_dictionary(example):
    features = {}
    for feat in [contains_1400s_word_refined_list,contains_1500s_word_refined_list,contains_new_word_refined_list,contains_new_word_large_list]: 
        features.update(feat(example))
    return features

# %%
from nltk.classify import NaiveBayesClassifier
import random

train = [(create_feature_dictionary(ex), "1400s") for ex in samples_1400s] + \
        [(create_feature_dictionary(ex), "1500s") for ex in samples_1500s] + \
        [(create_feature_dictionary(ex), "1600s") for ex in samples_1600s] + \
        [(create_feature_dictionary(ex), "1700s") for ex in samples_1700s] + \
        [(create_feature_dictionary(ex), "1800s") for ex in samples_1800s] + \
        [(create_feature_dictionary(ex), "1900s") for ex in samples_1900s]

random.seed(42)
random.shuffle(train)

split_percent = .2

cutoff = int(split_percent * len(train))

validation_set = train[:cutoff]
training_set = train[cutoff:]

model = NaiveBayesClassifier.train(training_set)
from nltk.classify.util import accuracy
print('Model that based only on the precence or absense of refined list of words')
print("Baseline of performance is 1/6 = .167, accuracy we would expect if we chose the same label every time.")
print('Validation accuracy: {}'.format(accuracy(model, validation_set)))
print(model.show_most_informative_features(10))
# Out:
# Model that based only on the precence or absense of refined list of words
# Baseline of performance is 1/6 = .167, accuracy we would expect if we chose the same label every time.
# Validation accuracy: 0.42916666666666664
# Most Informative Features
#                    thyng = 1               1400s : 1500s  =     37.7 : 1.0
#                       ii = 1               1400s : 1800s  =     30.1 : 1.0
#                     sins = 1               1400s : 1500s  =     25.2 : 1.0
#                 interest = 1               1700s : 1500s  =     24.9 : 1.0
#                remission = 1               1400s : 1600s  =     20.1 : 1.0
#                       52 = 1               1400s : 1700s  =     15.2 : 1.0
#                     nowe = 1               1400s : 1800s  =     14.5 : 1.0
#                      us_ = 1               1400s : 1700s  =     12.3 : 1.0
#                     holy = 1               1400s : 1800s  =     11.2 : 1.0
#                    class = 1               1700s : 1600s  =     10.8 : 1.0
# None

# %%
def create_feature_dictionary(example):
    features = {}
    for feat in [contains_1400s_word_refined_list,contains_1500s_word_refined_list,contains_new_word_refined_list,contains_new_word_large_list]: 
        features.update(feat(example))
    return features

# %%
train = [(create_feature_dictionary(ex), "1400s") for ex in samples_1400s] + \
        [(create_feature_dictionary(ex), "1500s") for ex in samples_1500s] + \
        [(create_feature_dictionary(ex), "1600s") for ex in samples_1600s] + \
        [(create_feature_dictionary(ex), "1700s") for ex in samples_1700s] + \
        [(create_feature_dictionary(ex), "1800s") for ex in samples_1800s] + \
        [(create_feature_dictionary(ex), "1900s") for ex in samples_1900s]

model = NaiveBayesClassifier.train(training_set)
print('Validation accuracy: {}'.format(accuracy(model, validation_set)))
print(model.show_most_informative_features(10))
